# %% [markdown]
# <a href="https://colab.research.google.com/github/Nivesri03/DSI/blob/main/Beginners_numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data=pd.read_csv('/content/drive/MyDrive/kpopgroups.csv')
print (data.head())
# Out:
#        Name Short Korean Name  Gender       Debut    Company  Members  \
# 0  (G)I-DLE   NaN     (여자)아이들  Female   2/05/2018       Cube        5
# 1      100%   NaN        백퍼센트    Male  18/09/2012  TOP Media        4
# 2       14U   NaN         원포유    Male  17/04/2017         BG       14
# 3       15&   NaN       피프틴앤드  Female   5/10/2012        JYP        2
# 4     1TEAM   NaN          원팀    Male  27/03/2019  LiveWorks        5
#
#    Orig Memb Fanclub Name Active
# 0          6          NaN    Yes
# 1          7   Perfection    Yes
# 2         14          NaN     No
# 3          2          NaN     No
# 4          5          NaN     No

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from subprocess import check_output
import os

# %%
data.info()
data.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          426 non-null    object
#  1   Short         53 non-null     object
#  2   Korean Name   426 non-null    object
#  3   Gender        426 non-null    object
#  4   Debut         424 non-null    object
#  5   Company       425 non-null    object
#  6   Members       426 non-null    int64
#  7   Orig Memb     426 non-null    int64
#  8   Fanclub Name  141 non-null    object
#  9   Active        426 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 33.4+ KB
# <ipython-input-10-9ed721eb09a5>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#             Members  Orig Memb
# ...

# %%
data.head(10)
# Out:
#        Name Short Korean Name  Gender       Debut       Company  Members  \
# 0  (G)I-DLE   NaN     (여자)아이들  Female   2/05/2018          Cube        5
# 1      100%   NaN        백퍼센트    Male  18/09/2012     TOP Media        4
# 2       14U   NaN         원포유    Male  17/04/2017            BG       14
# 3       15&   NaN       피프틴앤드  Female   5/10/2012           JYP        2
# 4     1TEAM   NaN          원팀    Male  27/03/2019     LiveWorks        5
# 5     1the9   NaN        원더나인    Male   9/02/2019           MBK        9
# 6       24K   NaN        투포케이    Male   6/09/2012        Choeun        5
# 7       2AM   NaN        투에이엠    Male  21/06/2008  JYP| Big Hit        4
# 8     2EYES   NaN        투아이즈  Female  20/07/2013       SidusHQ        4
# 9      2NE1   NaN        투애니원  Female   6/05/2009            YG        4
#
#    Orig Memb Fanclub Name Active
# 0          6          NaN    Yes
# 1          7   Perfection    Yes
# 2         14          NaN     No
# ...

# %% [markdown]
# MATPLOTLIB

# %%
data.plot(kind = 'line', color = 'g',label = 'Speed',linewidth=1,alpha = 0.5,grid = True,linestyle = ':')
data.plot(color = 'r',label = 'Defense',linewidth=1, alpha = 0.5,grid = True,linestyle = '-.')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %% [markdown]
# SCATTER GRAPH

# %%
data.plot(kind='scatter', x='Members', y='Orig Memb',alpha = 0.5,color = 'red')
plt.xlabel('MEMBERS')              # label = name of label
plt.ylabel('ORIGINAL MEMBERS')
plt.title('K-POP IDOLS')            # title = title of plot
# Out:
# Text(0.5, 1.0, 'K-POP IDOLS')

# %% [markdown]
# HISTOGRAM

# %%
data.plot(kind = 'hist',bins = 50,figsize = (12,12))
plt.show()

# %% [markdown]
# DICTIONARY

# %%
dictionary = {'spain' : 'madrid','usa' : 'vegas'}
print(dictionary.keys())
print(dictionary.values())
# Out:
# dict_keys(['spain', 'usa'])
# dict_values(['madrid', 'vegas'])

# %%
dictionary['spain'] = "barcelona"    # update existing entry
print(dictionary)
dictionary['france'] = "paris"       # Add new entry
print(dictionary)
del dictionary['spain']              # remove entry with key 'spain'
print(dictionary)
print('france' in dictionary)        # check include or not
dictionary.clear()                   # remove all entries in dict
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas'}
# {'spain': 'barcelona', 'usa': 'vegas', 'france': 'paris'}
# {'usa': 'vegas', 'france': 'paris'}
# True
# {}

# %% [markdown]
# PANDAS

# %%
data = pd.read_csv('/content/drive/MyDrive/kpopgroups.csv')
series = data['Name']        # data['Defense'] = series
print(type(series))
data_frame = data[['Name']]  # data[['Defense']] = data frame
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
print(3 > 2)
print(3!=2)
# Boolean operators
print(True and False)
print(True or False)
# Out:
# True
# True
# False
# True

# %%
x = data['Members']>200
data[x]
# Out:
# Empty DataFrame
# Columns: [Name, Short, Korean Name, Gender, Debut, Company, Members, Orig Memb, Fanclub Name, Active]
# Index: []

# %%
data[(data['Members']>200) & (data['Orig Memb']>100)]
# Out:
# Empty DataFrame
# Columns: [Name, Short, Korean Name, Gender, Debut, Company, Members, Orig Memb, Fanclub Name, Active]
# Index: []

# %% [markdown]
# LOOPS

# %%
i = 0
while i != 5 :
    print('i is: ',i)
    i +=1
print(i,' is equal to 5')
# Out:
# i is:  0
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# 5  is equal to 5

# %%
lis = [1,2,3,4,5]
for i in lis:
    print('i is: ',i)
print('')
for index, value in enumerate(lis):
    print(index," : ",value)
print('')
dictionary = {'spain':'madrid','france':'paris'}
for key,value in dictionary.items():
    print(key," : ",value)
print('')
# Out:
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5
#
# 0  :  1
# 1  :  2
# 2  :  3
# 3  :  4
# 4  :  5
#
# spain  :  madrid
# france  :  paris

# %% [markdown]
# USER DEFINED FUNCTION

# %%
def tuple_ex():
    """ return defined t tuple"""
    t = (1,2,3)
    return t
a,b,c = tuple_ex()
print(a,b,c)
# Out:
# 1 2 3

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
# ...

# %% [markdown]
# NESTED FUNCTION

# %%
def square():
    """ return square of value """
    def add():
        """ add two local variable """
        x = 2
        y = 3
        z = x + y
        return z
    return add()**2
print(square())
# Out:
# 25

# %%
def f(a, b = 1, c = 2):
    y = a + b + c
    return y
print(f(5))
# what if we want to change default arguments
print(f(5,4,3))
# Out:
# 8
# 12

# %%
# flexible arguments *args
def f(*args):
    for i in args:
        print(i)
f(1)
print("")
f(1,2,3,4)
# flexible arguments **kwargs that is dictionary
def f(**kwargs):
    """ print key and value of dictionary"""
    for key, value in kwargs.items():               # If you do not understand this part turn for loop part and look at dictionary in for loop
        print(key, " ", value)
f(country = 'spain', capital = 'madrid', population = 123456)
# Out:
# 1
#
# 1
# 2
# 3
# 4
# country   spain
# capital   madrid
# population   123456

# %% [markdown]
# LAMBDA FUNCTION

# %%
square = lambda x: x**2     # where x is name of argument
print(square(4))
tot = lambda x,y,z: x+y+z   # where x,y,z are names of arguments
print(tot(1,2,3))
# Out:
# 16
# 6

# %% [markdown]
# ANONYMOUS FUNCTION

# %%
number_list = [1,2,3]
y = map(lambda x:x**2,number_list)
print(list(y))
# Out:
# [1, 4, 9]

# %% [markdown]
# ITERATIONS

# %%
# iteration example
name = "BTS"
it = iter(name)
print(next(it))    # print next iteration
print(*it)         # print remaining iteration
# Out:
# B
# T S

# %% [markdown]
# ZIP() FUNCTION

# %%
list1 = [1,2,3,4]
list2 = [5,6,7,8]
z = zip(list1,list2)
print(z)
z_list = list(z)
print(z_list)
# Out:
# ...
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
un_zip = zip(*z_list)
un_list1,un_list2 = list(un_zip) # unzip returns tuple
print(un_list1)
print(un_list2)
print(type(un_list2))
# Out:
# (1, 2, 3, 4)
# (5, 6, 7, 8)
# <class 'tuple'>

# %% [markdown]
# LIST COMPREHENSION

# %%
num1 = [1,2,3]
num2 = [i + 1 for i in num1 ]
print(num2)
# Out:
# [2, 3, 4]

# %%
threshold = sum(data.Members)/len(data.Members)
data["Orig Memb"] = ["high" if i > threshold else "low" for i in data.Members]
data.loc[:10,["Orig Memb","Members"]]
# Out:
#    Orig Memb  Members
# 0        low        5
# 1        low        4
# 2       high       14
# 3        low        2
# 4        low        5
# 5       high        9
# 6        low        5
# 7        low        4
# 8        low        4
# 9        low        4
# 10      high        6

# %% [markdown]
# CLEANING DATA

# %%
data = pd.read_csv('/content/drive/MyDrive/kpopgroups.csv')
data.head()
# Out:
#        Name Short Korean Name  Gender       Debut    Company  Members  \
# 0  (G)I-DLE   NaN     (여자)아이들  Female   2/05/2018       Cube        5
# 1      100%   NaN        백퍼센트    Male  18/09/2012  TOP Media        4
# 2       14U   NaN         원포유    Male  17/04/2017         BG       14
# 3       15&   NaN       피프틴앤드  Female   5/10/2012        JYP        2
# 4     1TEAM   NaN          원팀    Male  27/03/2019  LiveWorks        5
#
#    Orig Memb Fanclub Name Active
# 0          6          NaN    Yes
# 1          7   Perfection    Yes
# 2         14          NaN     No
# 3          2          NaN     No
# 4          5          NaN     No

# %%
data.tail()
# Out:
#            Name Short Korean Name  Gender       Debut         Company  \
# 421      XODIAC   NaN         소디엑    Male  25/03/2023  One Cool Jacso
# 422         XUM   NaN           썸  Female  22/09/2020            A100
# 423  Yellow Bee   NaN         옐로비  Female  23/11/2017       Addiction
# 424     YOUNITE   NaN        유나이트    Male  20/04/2022       Brand New
# 425        ZE:A   NaN     제국의 아이들    Male   7/01/2010     Star Empire
#
#      Members  Orig Memb Fanclub Name  Active
# 421        9          9          NaN     Yes
# 422        3          3       AWEXUM      No
# 423        5          5          NaN      No
# 424        9          9       YOUNIZ     Yes
# 425        9          9   ZE:A Style  Hiatus

# %%
data.columns
# Out:
# Index(['Name', 'Short', 'Korean Name', 'Gender', 'Debut', 'Company', 'Members',
#        'Orig Memb', 'Fanclub Name', 'Active'],
#       dtype='object')

# %%
data.shape
# Out:
# (426, 10)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 426 entries, 0 to 425
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          426 non-null    object
#  1   Short         53 non-null     object
#  2   Korean Name   426 non-null    object
#  3   Gender        426 non-null    object
#  4   Debut         424 non-null    object
#  5   Company       425 non-null    object
#  6   Members       426 non-null    int64
#  7   Orig Memb     426 non-null    int64
#  8   Fanclub Name  141 non-null    object
#  9   Active        426 non-null    object
# dtypes: int64(2), object(8)
# memory usage: 33.4+ KB

# %% [markdown]
# EXPLORATORY DATA ANALYSIS

# %%
data.describe()
# Out:
#           Members   Orig Memb
# count  426.000000  426.000000
# mean     5.575117    5.978873
# std      2.246093    2.420894
# min      1.000000    2.000000
# 25%      4.000000    5.000000
# 50%      5.000000    6.000000
# 75%      7.000000    7.000000
# max     23.000000   24.000000

# %% [markdown]
#  VISUAL EXPLORATORY DATA ANALYSIS

# %%
data.boxplot(column='Members',by = 'Orig Memb')
# Out:
# <Axes: title={'center': 'Members'}, xlabel='Orig Memb'>

# %% [markdown]
# TIDY DATA

# %%
data_new = data.head()
data_new
# Out:
#        Name Short Korean Name  Gender       Debut    Company  Members  \
# 0  (G)I-DLE   NaN     (여자)아이들  Female   2/05/2018       Cube        5
# 1      100%   NaN        백퍼센트    Male  18/09/2012  TOP Media        4
# 2       14U   NaN         원포유    Male  17/04/2017         BG       14
# 3       15&   NaN       피프틴앤드  Female   5/10/2012        JYP        2
# 4     1TEAM   NaN          원팀    Male  27/03/2019  LiveWorks        5
#
#    Orig Memb Fanclub Name Active
# 0          6          NaN    Yes
# 1          7   Perfection    Yes
# 2         14          NaN     No
# 3          2          NaN     No
# 4          5          NaN     No

# %%
melted = pd.melt(frame=data_new,id_vars = 'Name', value_vars= ['Name','Korean Name'])
melted
# Out:
#        Name     variable    value
# 0  (G)I-DLE  Korean Name  (여자)아이들
# 1      100%  Korean Name     백퍼센트
# 2       14U  Korean Name      원포유
# 3       15&  Korean Name    피프틴앤드
# 4     1TEAM  Korean Name       원팀

# %% [markdown]
# PIVOTING DATA

# %%
melted.pivot(index = 'Name', columns = 'variable',values='value')
# Out:
# variable Korean Name
# Name
# (G)I-DLE     (여자)아이들
# 100%            백퍼센트
# 14U              원포유
# 15&            피프틴앤드
# 1TEAM             원팀

# %% [markdown]
# CONCATENATING DATA

# %%
data1 = data.head()
data2= data.tail()
conc_data_row = pd.concat([data1,data2],axis =0,ignore_index =True) # axis = 0 : adds dataframes in row
conc_data_row
# Out:
#          Name Short Korean Name  Gender       Debut         Company  Members  \
# 0    (G)I-DLE   NaN     (여자)아이들  Female   2/05/2018            Cube        5
# 1        100%   NaN        백퍼센트    Male  18/09/2012       TOP Media        4
# 2         14U   NaN         원포유    Male  17/04/2017              BG       14
# 3         15&   NaN       피프틴앤드  Female   5/10/2012             JYP        2
# 4       1TEAM   NaN          원팀    Male  27/03/2019       LiveWorks        5
# 5      XODIAC   NaN         소디엑    Male  25/03/2023  One Cool Jacso        9
# 6         XUM   NaN           썸  Female  22/09/2020            A100        3
# 7  Yellow Bee   NaN         옐로비  Female  23/11/2017       Addiction        5
# 8     YOUNITE   NaN        유나이트    Male  20/04/2022       Brand New        9
# 9        ZE:A   NaN     제국의 아이들    Male   7/01/2010     Star Empire        9
#
#    Orig Memb Fanclub Name  Active
# 0          6          NaN     Yes
# 1          7   Perfection     Yes
# ...

# %%
data1 = data['Debut'].head()
data2= data['Company'].head()
conc_data_col = pd.concat([data1,data2],axis =1)
conc_data_col
# Out:
#         Debut    Company
# 0   2/05/2018       Cube
# 1  18/09/2012  TOP Media
# 2  17/04/2017         BG
# 3   5/10/2012        JYP
# 4  27/03/2019  LiveWorks

# %% [markdown]
# DATA TYPES

# %%
data.dtypes
# Out:
# Name            object
# Short           object
# Korean Name     object
# Gender          object
# Debut           object
# Company         object
# Members          int64
# Orig Memb        int64
# Fanclub Name    object
# Active          object
# dtype: object

# %% [markdown]
# VISUALIZATION

# %%
data1 = data.loc[:,["Members","Orig Memb"]]
data1.plot()
# Out:
# <Axes: >

# %%
data1.plot(subplots = True)
plt.show()

# %%
# scatter plot
data1.plot(kind = "scatter",x="Orig Memb",y = "Members")
plt.show()

# %%
data1.plot(kind = "hist",y = "Members",bins = 50,range= (0,250))
# Out:
# <Axes: ylabel='Frequency'>

# %%
time_list = ["1992-03-08","1992-04-12"]
print(type(time_list[1]))
# Out:
# <class 'str'>

# %%
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
import warnings
warnings.filterwarnings("ignore")
# In order to practice lets take head of pokemon data and add it a time list
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
# lets make date as index
data2= data2.set_index("date")
data2
# Out:
#                 Name Short Korean Name  Gender       Debut    Company  \
# date
# 1992-01-10  (G)I-DLE   NaN     (여자)아이들  Female   2/05/2018       Cube
# 1992-02-10      100%   NaN        백퍼센트    Male  18/09/2012  TOP Media
# 1992-03-10       14U   NaN         원포유    Male  17/04/2017         BG
# 1993-03-15       15&   NaN       피프틴앤드  Female   5/10/2012        JYP
# 1993-03-16     1TEAM   NaN          원팀    Male  27/03/2019  LiveWorks
#
#             Members  Orig Memb Fanclub Name Active
# date
# 1992-01-10        5          6          NaN    Yes
# 1992-02-10        4          7   Perfection    Yes
# 1992-03-10       14         14          NaN     No
# 1993-03-15        2          2          NaN     No
# 1993-03-16        5          5          NaN     No

# %%
print(data2.loc["1993-03-16"])
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
# Name                 1TEAM
# Short                  NaN
# Korean Name             원팀
# Gender                Male
# Debut           27/03/2019
# Company          LiveWorks
# Members                  5
# Orig Memb                5
# Fanclub Name           NaN
# Active                  No
# Name: 1993-03-16 00:00:00, dtype: object
#              Name Short Korean Name  Gender       Debut    Company  Members  \
# date
# 1992-03-10    14U   NaN         원포유    Male  17/04/2017         BG       14
# 1993-03-15    15&   NaN       피프틴앤드  Female   5/10/2012        JYP        2
# 1993-03-16  1TEAM   NaN          원팀    Male  27/03/2019  LiveWorks        5
#
#             Orig Memb Fanclub Name Active
# date
# 1992-03-10         14          NaN     No
# 1993-03-15          2          NaN     No
# 1993-03-16          5          NaN     No

# %% [markdown]
# RESAMPLING PANDAS TIME SERIES

# %%
data2.resample("A").mean()
# Out:
#              Members  Orig Memb
# date
# 1992-12-31  7.666667        9.0
# 1993-12-31  3.500000        3.5

# %%
data2.resample("M").mean()
# Out:
#             Members  Orig Memb
# date
# 1992-01-31      5.0        6.0
# 1992-02-29      4.0        7.0
# 1992-03-31     14.0       14.0
# 1992-04-30      NaN        NaN
# 1992-05-31      NaN        NaN
# 1992-06-30      NaN        NaN
# 1992-07-31      NaN        NaN
# 1992-08-31      NaN        NaN
# 1992-09-30      NaN        NaN
# 1992-10-31      NaN        NaN
# 1992-11-30      NaN        NaN
# 1992-12-31      NaN        NaN
# 1993-01-31      NaN        NaN
# 1993-02-28      NaN        NaN
# 1993-03-31      3.5        3.5

# %%
data2.resample("M").first().interpolate("linear")
# Out:
#                 Name Short Korean Name  Gender       Debut    Company  \
# date
# 1992-01-31  (G)I-DLE  None     (여자)아이들  Female   2/05/2018       Cube
# 1992-02-29      100%  None        백퍼센트    Male  18/09/2012  TOP Media
# 1992-03-31       14U  None         원포유    Male  17/04/2017         BG
# 1992-04-30      None  None        None    None        None       None
# 1992-05-31      None  None        None    None        None       None
# 1992-06-30      None  None        None    None        None       None
# 1992-07-31      None  None        None    None        None       None
# 1992-08-31      None  None        None    None        None       None
# 1992-09-30      None  None        None    None        None       None
# 1992-10-31      None  None        None    None        None       None
# 1992-11-30      None  None        None    None        None       None
# 1992-12-31      None  None        None    None        None       None
# ...

# %%
data2.resample("M").mean().interpolate("linear")
# Out:
#             Members  Orig Memb
# date
# 1992-01-31    5.000      6.000
# 1992-02-29    4.000      7.000
# 1992-03-31   14.000     14.000
# 1992-04-30   13.125     13.125
# 1992-05-31   12.250     12.250
# 1992-06-30   11.375     11.375
# 1992-07-31   10.500     10.500
# 1992-08-31    9.625      9.625
# 1992-09-30    8.750      8.750
# 1992-10-31    7.875      7.875
# 1992-11-30    7.000      7.000
# 1992-12-31    6.125      6.125
# 1993-01-31    5.250      5.250
# 1993-02-28    4.375      4.375
# 1993-03-31    3.500      3.500

# %%
data2.resample("M").mean().interpolate("linear")
# Out:
#             Members  Orig Memb
# date
# 1992-01-31    5.000      6.000
# 1992-02-29    4.000      7.000
# 1992-03-31   14.000     14.000
# 1992-04-30   13.125     13.125
# 1992-05-31   12.250     12.250
# 1992-06-30   11.375     11.375
# 1992-07-31   10.500     10.500
# 1992-08-31    9.625      9.625
# 1992-09-30    8.750      8.750
# 1992-10-31    7.875      7.875
# 1992-11-30    7.000      7.000
# 1992-12-31    6.125      6.125
# 1993-01-31    5.250      5.250
# 1993-02-28    4.375      4.375
# 1993-03-31    3.500      3.500

# %% [markdown]
# INDEXING DATAFRAMES

# %%
data = pd.read_csv('/content/drive/MyDrive/kpopgroups.csv')
data= data.set_index("Korean Name")
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e58577f04734> in <cell line: 1>()
# ----> 1 data = pd.read_csv('/content/drive/MyDrive/kpopgroups.csv')
#       2 data= data.set_index("Korean Name")
#       3 data.head()
#
# NameError: name 'pd' is not defined

# %%
data["Company"][1]
# Out:
# 'TOP Media'

# %%
data[["Name","Debut"]]
# Out:
#                    Name       Debut
# Korean Name
# (여자)아이들        (G)I-DLE   2/05/2018
# 백퍼센트               100%  18/09/2012
# 원포유                 14U  17/04/2017
# 피프틴앤드               15&   5/10/2012
# 원팀                1TEAM  27/03/2019
# ...                 ...         ...
# 소디엑              XODIAC  25/03/2023
# 썸                   XUM  22/09/2020
# 옐로비          Yellow Bee  23/11/2017
# 유나이트            YOUNITE  20/04/2022
# 제국의 아이들            ZE:A   7/01/2010
#
# [426 rows x 2 columns]

# %% [markdown]
# INDEX OBJECTS AND LABELED DATA

# %%
print(data.index.name)
# lets change it
data.index.name = "index_name"
data.head()
# Out:
# Korean Name
#                 Name Short  Gender       Debut    Company  Members  Orig Memb  \
# index_name
# (여자)아이들     (G)I-DLE   NaN  Female   2/05/2018       Cube        5          6
# 백퍼센트            100%   NaN    Male  18/09/2012  TOP Media        4          7
# 원포유              14U   NaN    Male  17/04/2017         BG       14         14
# 피프틴앤드            15&   NaN  Female   5/10/2012        JYP        2          2
# 원팀             1TEAM   NaN    Male  27/03/2019  LiveWorks        5          5
#
#            Fanclub Name Active
# index_name
# (여자)아이들             NaN    Yes
# 백퍼센트         Perfection    Yes
# 원포유                 NaN     No
# 피프틴앤드               NaN     No
# 원팀                  NaN     No

# %%
data.head()
data3 = data.copy()
data3.head()
# Out:
#                 Name Short  Gender       Debut    Company  Members  Orig Memb  \
# index_name
# (여자)아이들     (G)I-DLE   NaN  Female   2/05/2018       Cube        5          6
# 백퍼센트            100%   NaN    Male  18/09/2012  TOP Media        4          7
# 원포유              14U   NaN    Male  17/04/2017         BG       14         14
# 피프틴앤드            15&   NaN  Female   5/10/2012        JYP        2          2
# 원팀             1TEAM   NaN    Male  27/03/2019  LiveWorks        5          5
#
#            Fanclub Name Active
# index_name
# (여자)아이들             NaN    Yes
# 백퍼센트         Perfection    Yes
# 원포유                 NaN     No
# 피프틴앤드               NaN     No
# 원팀                  NaN     No

# %% [markdown]
# PIVOTING DATAFRAMES

# %%
dic = {"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
df = pd.DataFrame(dic)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-8834f5dfde75> in <cell line: 2>()
#       1 dic = {"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
# ----> 2 df = pd.DataFrame(dic)
#       3 df
#
# NameError: name 'pd' is not defined

# %%
df.pivot(index="treatment",columns = "gender",values="response")
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %% [markdown]
# STACKING AND UNSTACKING DATAFRAME

# %%
df1 = df.set_index(["treatment","gender"])
df1
# Out:
#                   response  age
# treatment gender
# A         F             10   15
#           M             45    4
# B         F              5   72
#           M              9   65

# %%
df1.unstack(level=0)
# Out:
#           response    age
# treatment        A  B   A   B
# gender
# F               10  5  15  72
# M               45  9   4  65

# %%
df1.unstack(level=1)
# Out:
#           response     age
# gender           F   M   F   M
# treatment
# A               10  45  15   4
# B                5   9  72  65

# %% [markdown]
# MELTING DATA FRAMES

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
pd.melt(df,id_vars="treatment",value_vars=["age","response"])
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %% [markdown]
# CATEGORICALS AND GROUPBY

# %%
df.groupby("treatment").mean()
# Out:
#            response   age
# treatment
# A              27.5   9.5
# B               7.0  68.5

# %%
df.groupby("treatment").age.max()
# Out:
# treatment
# A    15
# B    72
# Name: age, dtype: int64

# %%
df.groupby("treatment")[["age","response"]].min()
# Out:
#            age  response
# treatment
# A            4        10
# B           65         5

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a74c58233b9e> in <cell line: 1>()
# ----> 1 df.info()
#
# NameError: name 'df' is not defined
